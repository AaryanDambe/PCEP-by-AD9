# %%
for attribute in seq:
    for attribute1 in seq1:
        block __of--> instruction

# %%
for var in range(start,stop,step):
    for var1 in range(start,stop,step):
        block_of-->Instruction

# %%
###printing tables
for i in range(1,11):
    for j in range(1,13):
        print(f'{i}x{j} = {i*j}')
    print('\n')
# Out:
# 1x1 = 1
# 1x2 = 2
# 1x3 = 3
# 1x4 = 4
# 1x5 = 5
# 1x6 = 6
# 1x7 = 7
# 1x8 = 8
# 1x9 = 9
# 1x10 = 10
# 1x11 = 11
# 1x12 = 12
#
#
# 2x1 = 2
# 2x2 = 4
# 2x3 = 6
# 2x4 = 8
# 2x5 = 10
# 2x6 = 12
# 2x7 = 14
# 2x8 = 16
# 2x9 = 18
# 2x10 = 20
# 2x11 = 22
# 2x12 = 24
#
#
# 3x1 = 3
# 3x2 = 6
# 3x3 = 9
# 3x4 = 12
# 3x5 = 15
# 3x6 = 18
# 3x7 = 21
# 3x8 = 24
# 3x9 = 27
# 3x10 = 30
# 3x11 = 33
# 3x12 = 36
#
#
# 4x1 = 4
# 4x2 = 8
# 4x3 = 12
# 4x4 = 16
# 4x5 = 20
# 4x6 = 24
# 4x7 = 28
# 4x8 = 32
# 4x9 = 36
# 4x10 = 40
# 4x11 = 44
# 4x12 = 48
#
#
# 5x1 = 5
# 5x2 = 10
# 5x3 = 15
# 5x4 = 20
# 5x5 = 25
# 5x6 = 30
# 5x7 = 35
# 5x8 = 40
# 5x9 = 45
# 5x10 = 50
# 5x11 = 55
# 5x12 = 60
#
#
# 6x1 = 6
# 6x2 = 12
# 6x3 = 18
# 6x4 = 24
# 6x5 = 30
# 6x6 = 36
# 6x7 = 42
# 6x8 = 48
# 6x9 = 54
# 6x10 = 60
# 6x11 = 66
# 6x12 = 72
#
#
# 7x1 = 7
# 7x2 = 14
# 7x3 = 21
# 7x4 = 28
# 7x5 = 35
# 7x6 = 42
# 7x7 = 49
# 7x8 = 56
# 7x9 = 63
# 7x10 = 70
# 7x11 = 77
# 7x12 = 84
#
#
# 8x1 = 8
# 8x2 = 16
# 8x3 = 24
# 8x4 = 32
# ...

# %% [markdown]
# <h1>Q1) Homework of calcuoator with nested for loop and asking for calculating num1-num2 or num2=num1</h1>
